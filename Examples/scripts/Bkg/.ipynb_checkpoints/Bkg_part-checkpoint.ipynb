# %%
A0 = 1.0e-5
A1 = 1.0e-9
A2 = 1.0e-9
A3 = 1.0e-9
sigma = 1

inputfile='blank_bkg.fits'
#inputfile='bck_filled.fits'

# %% [markdown]
# # Code

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

from pylab import rcParams
rcParams['figure.figsize'] = 9, 9

from astropy.io import fits
from astropy import table

import random

# %%
file=fits.open(inputfile)

# %%
#file.info()
#print(file[0].data)

# %% [markdown]
# ## Value distribution

# %%
l = len(file[0].data)
mu = A0

# %%
x=np.linspace(-l/2,l/2, num=l)
y=np.linspace(-l/2,l/2, num=l)

x, y = np.meshgrid(x, y)

z = np.random.normal(mu, sigma, (l, l))
z = np.abs(z)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x,y,z, cmap=cm.jet)
plt.show()

print(z)
# Out:
# [[0.80529852 0.38922077 0.21801631 ... 2.15383921 1.0518759  0.05396183]
#  [0.29123185 0.68158367 0.25229053 ... 1.05611242 0.96397153 0.0671184 ]
#  [1.21380367 1.10714805 0.98826314 ... 1.08343077 1.02606755 0.82718324]
#  ...
#  [1.52529249 1.29693144 0.7599035  ... 0.47699696 0.92162078 0.55943485]
#  [1.09350821 1.45236199 0.53462335 ... 0.30117208 1.20677143 0.30549885]
#  [1.51100839 0.2324983  0.18535177 ... 0.82668325 1.94321471 0.38007649]]

# %% [markdown]
# ## Multiples (parameter maps)

# %%
#se parti da un file diverso da blank_bkg usa questo e commenta la riga con *=z
#z = file[0].data[:][:]*A0

file[0].data[:][:] = z*A0

print(file[0].data)
file.writeto('fake_part_bkg.fits', overwrite=True)

#######################################################################################

file[0].data[:][:] = z*A0

file[0].data[:][:] *= A1
print(file[0].data)
file.writeto('part_norm1.fits', overwrite=True)

#######################################################################################

file[0].data[:][:] = z*A0

file[0].data[:][:] *= A2
print(file[0].data)
file.writeto('part_norm2.fits', overwrite=True)

#######################################################################################

file[0].data[:][:] = z*A0

file[0].data[:][:] *= A3
print(file[0].data)
file.writeto('part_norm3.fits', overwrite=True)
# Out:
# [[8.05298532e-06 3.89220759e-06 2.18016316e-06 ... 2.15383916e-05
#   1.05187592e-05 5.39618327e-07]
#  [2.91231845e-06 6.81583651e-06 2.52290533e-06 ... 1.05611243e-05
#   9.63971524e-06 6.71184011e-07]
#  [1.21380363e-05 1.10714809e-05 9.88263128e-06 ... 1.08343074e-05
#   1.02606755e-05 8.27183248e-06]
#  ...
#  [1.52529246e-05 1.29693144e-05 7.59903514e-06 ... 4.76996956e-06
#   9.21620813e-06 5.59434829e-06]
#  [1.09350822e-05 1.45236199e-05 5.34623359e-06 ... 3.01172076e-06
